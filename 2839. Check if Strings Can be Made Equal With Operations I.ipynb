# %%
def canBeEqual(s1, s2):
    v1 = s1[2] + s1[1] + s1[0] + s1[3]
    v2 = s1[0] + s1[3] + s1[2] + s1[1]
    v3 = s1[2] + s1[3] + s1[0] + s1[1]
    if s2==s1 or s2==v1 or s2==v2 or s2==v3:
        return True
    return False

# %%
s1 = "abcd"
s2 = "cdab"
canBeEqual(s1, s2)
# Out:
# True
