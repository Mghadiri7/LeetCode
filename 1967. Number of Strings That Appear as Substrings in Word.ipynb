# %%
def numOfStrings(patterns, word):
    ans = 0
    for p in patterns:
        if p in word:
            ans += 1
    return ans

# %%
patterns = ["a","abc","bc","d"]
word = "abc"
numOfStrings(patterns, word)
# Out:
# 3
