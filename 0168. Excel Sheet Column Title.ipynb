# %%
def convertToTitle(columnNumber):
    res = []
    while columnNumber > 0:
        columnNumber -= 1
        reminder = columnNumber % 26
        res.append(chr(reminder + 65))
        columnNumber //= 26

    return "".join(res[::-1])

# %%
columnNumber = 701
convertToTitle(columnNumber)
# Out:
# 'ZY'
