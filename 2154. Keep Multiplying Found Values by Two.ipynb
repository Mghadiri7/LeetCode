# %%
def findFinalValue(nums, original):
    _set = set(nums)
    while True:
        if original in _set:
            original *= 2
        else:
            return original

# %%
nums = [5,3,6,1,12]
original = 3
findFinalValue(nums, original)
# Out:
# 24
