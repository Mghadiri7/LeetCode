# %%
def gcdOfOddEvenSums(n):
    even = 0
    odd = 0
    # for i in range(1, n+1):
    #     even += 2*i
    #     odd += (2*i)-1
    even = n*(n+1)
    odd = n*n
    gcd = n
    return gcd

# %%
n = 5
gcdOfOddEvenSums(n)
# Out:
# 5
